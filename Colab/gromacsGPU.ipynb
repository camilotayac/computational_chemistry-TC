# %% [markdown]
# <a href="https://colab.research.google.com/github/camilotayac/computational_chemistry-TC/blob/master/Colab/gromacsGPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧙‍♂️ - ♾️ Análisis de Dinamica de Membrana
#
# 🐉 **@Tyac**
#
# 🏦 **Universidad de Caldas**
#
# 🌇 **Manizales - Colombia**

# %%
# @title # 0️⃣👻 **Recursos necesarios para el proceso y si quiere visualizar estructuras**
gromacs = "2023.2" # @param {"type":"string"}
# !pip install -q condacolab
import condacolab
condacolab.install()
#!conda install gromacs=2024.2=nompi_cuda*
### Sin GPU
# !conda install gromacs=$gromacs
# !gmx -version
# Out:
# Tue Sep 10 21:14:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - gromacs==2023.2[build=nompi_cuda*]
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     cudatoolkit-11.8.0         |      h4ba93d1_13       682.5 MB  conda-forge
#     fftw-3.3.10                |nompi_hf1063bd_110         2.0 MB  conda-forge
#     gromacs-2023.2             |nompi_cuda_h6303bc7_0        35.7 MB  conda-forge
#     libgcc-14.1.0              |       h77fa898_1         827 KB  conda-forge
#     libgcc-ng-14.1.0           |       h69a702a_1          51 KB  conda-forge
#     libgfortran-14.1.0         |       h69a702a_1          51 KB  conda-forge
#     libgfortran-ng-14.1.0      |       h69a702a_1          51 KB  conda-forge
#     libgfortran5-14.1.0        |       hc5f4f2c_1         1.4 MB  conda-forge
#     libgomp-14.1.0             |       h77fa898_1         449 KB  conda-forge
#     libhwloc-2.9.3             |default_h554bfaf_1009         2.5 MB  conda-forge
#     openssl-3.3.2              |       hb9d3cd8_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       728.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.8.0-h4ba93d1_13
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf1063bd_110
#   gromacs            conda-forge/linux-64::gromacs-2023.2-nompi_cuda_h6303bc7_0
#   libgcc             conda-forge/linux-64::libgcc-14.1.0-h77fa898_1
#   libgfortran        conda-forge/linux-64::libgfortran-14.1.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.1.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.1.0-hc5f4f2c_1
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.3-default_h554bfaf_1009
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.8.30-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.8.30-pyhd8ed1ab_0
#   libgcc-ng                               13.2.0-h807b86a_3 --> 14.1.0-h69a702a_1
#   libgomp                                 13.2.0-h807b86a_3 --> 14.1.0-h77fa898_1
#   openssl                                  3.2.0-hd590300_1 --> 3.3.2-hb9d3cd8_0
#
#
#
# Downloading and Extracting Packages:
# cudatoolkit-11.8.0   | 682.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
# gromacs-2023.2       | 35.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.3.2        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libhwloc-2.9.3       | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# fftw-3.3.10          | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgfortran5-14.1.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libgcc-14.1.0        | 827 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# certifi-2024.8.30    | 160 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.1. | 51 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 51 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   0% 0.0008242304847057805/1 [00:00<02:01, 121.40s/it]
#
# openssl-3.3.2        | 2.8 MB    | :   1% 0.005665696909421814/1 [00:00<00:17, 17.71s/it]
#
#
#
# fftw-3.3.10          | 2.0 MB    | :   1% 0.00789525296951432/1 [00:00<00:14, 14.42s/it]
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   1% 0.014355347608625679/1 [00:00<00:11, 12.08s/it]
#
#
#
#
#
# libgcc-14.1.0        | 827 KB    | :   2% 0.01935773529620265/1 [00:00<00:10, 10.46s/it]
#
#
#
#
# libgfortran5-14.1.0  | 1.4 MB    | :   1% 0.011222386688758914/1 [00:00<00:18, 18.58s/it]
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | :   4% 0.03560051975368195/1 [00:00<00:07,  7.90s/it]
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   2% 0.02262054774692531/1 [00:00<00:13, 13.70s/it]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | :  10% 0.10304208096702577/1 [00:00<00:02,  3.21s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.1. | 51 KB     | :  31% 0.3137975944227381/1 [00:00<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 51 KB     | :  31% 0.31405022043319913/1 [00:00<00:00,  1.13s/it]
# gromacs-2023.2       | 35.7 MB   | :   0% 0.00043800205725160607/1 [00:00<14:00, 840.69s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   3% 0.030038622109277335/1 [00:00<00:13, 13.81s/it]
#
#
#
# fftw-3.3.10          | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.32it/s]
# gromacs-2023.2       | 35.7 MB   | :   5% 0.04993223452668309/1 [00:00<00:06,  7.18s/it]
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   4% 0.042402079379864045/1 [00:00<00:10, 11.14s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :   5% 0.051537300585353114/1 [00:00<00:10, 11.51s/it]
# gromacs-2023.2       | 35.7 MB   | :  13% 0.13271462334723663/1 [00:00<00:03,  3.74s/it]
#
# openssl-3.3.2        | 2.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
#
# openssl-3.3.2        | 2.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
#
#
#
#
#
# libgcc-14.1.0        | 827 KB    | : 100% 1.0/1 [00:00<00:00,  1.60it/s]
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   6% 0.060351987713456595/1 [00:00<00:11, 11.73s/it]
# gromacs-2023.2       | 35.7 MB   | :  18% 0.1817708537594165/1 [00:00<00:02,  3.03s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :   7% 0.06896061722038364/1 [00:00<00:12, 13.04s/it]
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | : 100% 1.0/1 [00:00<00:00,  1.22it/s]
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | : 100% 1.0/1 [00:00<00:00,  1.22it/s]
#
#
#
#
#
#
#
# certifi-2024.8.30    | 160 KB    | : 100% 1.0/1 [00:00<00:00,  1.10it/s]
# gromacs-2023.2       | 35.7 MB   | :  34% 0.34339361288525916/1 [00:00<00:01,  1.73s/it]
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :   8% 0.07681370211633039/1 [00:00<00:12, 13.09s/it]
#
#
#
#
# libgfortran5-14.1.0  | 1.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.06it/s]
#
#
#
#
# libgfortran5-14.1.0  | 1.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.06it/s]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | : 100% 1.0/1 [00:01<00:00,  1.01it/s]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | : 100% 1.0/1 [00:01<00:00,  1.01it/s]
# cudatoolkit-11.8.0   | 682.5 MB  | :   8% 0.08457520584730982/1 [00:01<00:12, 13.58s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :   9% 0.09229091899580559/1 [00:01<00:12, 13.43s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.1. | 51 KB     | : 100% 1.0/1 [00:01<00:00,  1.28s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.1. | 51 KB     | : 100% 1.0/1 [00:01<00:00,  1.28s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :  10% 0.10035006151292879/1 [00:01<00:11, 13.20s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :  11% 0.10882131927240486/1 [00:01<00:11, 13.03s/it]
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 51 KB     | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :  12% 0.11710941470194632/1 [00:01<00:11, 12.80s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-14.1.0   | 51 KB     | : 100% 1.0/1 [00:01<00:00,  1.62s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :  16% 0.16212155728337868/1 [00:01<00:08,  9.85s/it]
#
#
# libhwloc-2.9.3       | 2.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.89s/it]
#
#
# cudatoolkit-11.8.0   | 682.5 MB  | :  58% 0.5769613392940464/1 [00:05<00:02,  5.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done

# %%
# @title ## 📁 Files for analysis ♾️ Archivos para el análisis
# @markdown ### **🇺🇸** - Select whether you will work with tutorial files or with your own files
# @markdown ### **🇪🇸** - Seleccione si va a trabajar con archivos del tutorial o con archivos propios
files = 'Own files - Archivos propios'# @param ['Tutorial files - Archivos del tutorial', 'Own files - Archivos propios']
# @markdown #### 🔴 **🇺🇸 - Note:** add the address of your folder, example: ***folder_a*** or ***folder_a/folder_b***
# @markdown #### 🔴 **🇪🇸 - Nota:** agregue la dirección de su carpeta, ejemplo: ***carpeta_a*** o ***carpeta_a/carpeta_b***
drive_folder_path = "MD/12" #@param {type:"string"}

if files == 'Tutorial files - Archivos del tutorial':
  # %cd /content
  # !git clone https://github.com/camilotayac/computational_chemistry-TC.git
  # %cd computational_chemistry-TC/Examples
elif files == 'Own files - Archivos propios':
  from google.colab import drive
  drive.mount('/content/drive')
  carpeta = "/content/drive/MyDrive/" + drive_folder_path
  # %cd {carpeta}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/MD/12
